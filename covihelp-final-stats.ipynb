# %%
import pandas as pd 
import matplotlib.pylab as plt
from datetime import date

# %%
df=pd.read_csv('final_df.csv')

# %%
df
# Out:
#       Unnamed: 0            Timestamp Name of the Patient  \
# 0              0  2021-04-27 18:26:37          Ali ashraf
# 1              1  2021-04-27 18:41:52         Rohit kumar
# 2              2  2021-04-27 18:57:44         Veena yadav
# 3              3  2021-04-27 18:58:52  Balbir singh yadav
# 4              4  2021-04-27 19:07:45      Parveen panday
# ...          ...                  ...                 ...
# 1438         675  2021-05-30 18:09:00                 NaN
# 1439         676  2021-05-30 18:26:00                 NaN
# 1440         677  2021-05-30 18:55:00                 NaN
# 1441         678  2021-05-30 18:58:00                 NaN
# 1442         679  2021-05-30 19:27:00                 NaN
#
#      Name of the username contacting us.      Age  Gender  \
# 0                                    NaN  Over 45    Male
# 1                                    NaN  Over 45    Male
# 2                                    NaN  Over 45  Female
# 3                                    NaN  Over 45    Male
# 4                                    NaN    18-45    Male
# ...                                  ...      ...     ...
# 1438                           IABD_KHAN      NaN     NaN
# 1439                     +91 80082 28833      NaN     NaN
# 1440                     +91 99132 22993      NaN     NaN
# 1441                    KHIALANIPRIYANKA      NaN     NaN
# 1442                     +91 94433 63809      NaN     NaN
#
#                                                Location Oxygen Level  \
# 0                                  Raza bazaar, patna\n        80-90
# 1                                 kaushambi, gaziabadh         80-90
# 2                                      Hauz khas, delhi        90-95
# 3                                       hauz khas,delhi        90-95
# 4                                               Gurgaon     Below 80
# ...                                                 ...          ...
# 1438                                          BANGALORE          NaN
# 1439                               HYDERABAD/ VIJAYWADA          NaN
# 1440  PRAYAGRAJ, JAGRITI HOSPITAL, CIVIL LINES, PRAY...          NaN
# 1441                                          AHMEDABAD          NaN
# 1442                                         COIMBATORE          NaN
#
#                Comorbidities         Physical Discomfort  ... Status Remarks  \
# 0                        NaN                         NaN  ...            NaN
# 1               Hypertension                       Fever  ...            NaN
# 2     Diabetes, Hypertension                         NaN  ...            NaN
# 3     Diabetes, Hypertension                         NaN  ...            NaN
# 4                   Diabetes  Chest Pain, Fever, Fatigue  ...            NaN
# ...                      ...                         ...  ...            ...
# 1438                     NaN                         NaN  ...            NaN
# 1439                     NaN                         NaN  ...            NaN
# 1440                     NaN                         NaN  ...            NaN
# 1441                     NaN                         NaN  ...            NaN
# 1442                     NaN                         NaN  ...            NaN
#
#      TimeStamp   Criticality       Status  Platform Prescription  Blood Type  \
# 0          NaN           NaN          NaN       NaN          NaN         NaN
# 1          NaN           NaN          NaN       NaN          NaN         NaN
# 2          NaN           NaN          NaN       NaN          NaN         NaN
# 3          NaN           NaN          NaN       NaN          NaN         NaN
# 4          NaN           NaN          NaN       NaN          NaN         NaN
# ...        ...           ...          ...       ...          ...         ...
# 1438       NaN  Non-Critical      Pending  Facebook          NaN         NaN
# 1439       NaN  Non-Critical  In Progress  Whatsapp          NaN         NaN
# 1440       NaN  Non-Critical  In Progress  Whatsapp          NaN          O-
# 1441       NaN  Non-Critical  In Progress  Facebook          NaN         NaN
# 1442       NaN  Non-Critical  In Progress  Whatsapp          NaN         NaN
#
#      Can Receive  Covid    RT-PCR
# 0            NaN    NaN       NaN
# 1            NaN    NaN       NaN
# 2            NaN    NaN       NaN
# 3            NaN    NaN       NaN
# 4            NaN    NaN       NaN
# ...          ...    ...       ...
# 1438         NaN  Covid  Positive
# 1439         NaN    NaN       NaN
# 1440     O- only    NaN       NaN
# 1441         NaN    NaN       NaN
# 1442         NaN    NaN       NaN
#
# [1443 rows x 28 columns]

# %%
print(df['Timestamp'].dtypes)
# date_list = df['Timestamp'].tolist()
# date_list = [date.date() for date in date_list]
# Out:
# object

# %%
data = df.groupby(["Timestamp","Unnamed: 0"]).size()
data
# Out:
# Timestamp            Unnamed: 0
# 2021-01-05 00:34:27  154           1
# 2021-01-05 01:29:16  540           1
# 2021-01-05 01:41:18  541           1
# 2021-01-05 02:18:19  450           1
# 2021-01-05 09:26:45  155           1
#                                   ..
# 2021-12-05 20:43:00  162           1
# 2021-12-05 21:07:00  163           1
# 2021-12-05 22:02:00  164           1
# 2021-12-05 22:07:00  165           1
# 2021-12-05 23:20:00  166           1
# Length: 1435, dtype: int64
